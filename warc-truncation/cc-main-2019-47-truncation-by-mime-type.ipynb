# %% [markdown]
# # Truncated Records in WARC Files (November 2019)
#
# Since November 2019 (CC-MAIN-2019-47) truncated records are marked in the URL indexes. This allows to analyze distribution of truncated records over the entire monthly crawl (November 2019 - CC-MAIN-2019-47).
#
# Counts of truncated records are aggregated per MIME type using [AWS Athena](https://aws.amazon.com/athena/) and the SQL query [average-warc-record-length-by-mime-type.sql](/commoncrawl/cc-index-table/blob/525ab8b16fee54a88706c0aa5aa453b4d7253d7b/src/sql/examples/cc-index/average-warc-record-length-by-mime-type.sql). The aggregations also include WARC record sizes.

# %%
import json
import pandas

data = pandas.read_csv('data/warc-record-size-truncation-by-mime-type-CC-MAIN-2019-47.csv')

data[['content_mime_detected', 'n_pages', 'perc_truncated', 'reasons_truncation']].head(20)
# Out:
#              content_mime_detected     n_pages  perc_truncated  \
# 0                        text/html  2002557402        0.757578
# 1            application/xhtml+xml   555659037        0.719266
# 2                  application/pdf    12206558       24.028182
# 3                       image/jpeg     3932068        9.780960
# 4              application/rss+xml     3424865        0.627499
# 5             application/atom+xml     3261205        0.128388
# 6                       text/plain     2068745        2.289891
# 7                  application/xml     1713357        5.201309
# 8                    text/calendar      959303        0.185030
# 9                 application/json      633507        0.397470
# 10                       image/png      584080        9.197884
# 11        application/octet-stream      329265        8.815999
# 12             application/rdf+xml      239943        0.533460
# 13                 application/zip      222256       33.397974
# 14                      audio/mpeg      147410       85.808290
# 15  application/x-bibtex-text-file      128140        0.018730
# 16                    text/x-vcard       95335        0.681806
# 17                      text/x-php       89228        0.318286
# 18                     text/x-perl       80012        0.057491
# 19     application/x-tika-msoffice       74780        9.943835
#
#                                  reasons_truncation
# 0   {disconnect=1265692, length=13904449, time=791}
# 1     {disconnect=817826, length=3178707, time=131}
# 2      {disconnect=11271, length=2921479, time=264}
# 3                  {disconnect=2065, length=382529}
# 4          {disconnect=2245, length=19236, time=10}
# 5                      {disconnect=24, length=4163}
# 6          {disconnect=3805, length=43556, time=11}
# 7           {disconnect=1894, length=87221, time=2}
# 8                     {disconnect=773, length=1002}
# 9                      {disconnect=13, length=2505}
# 10           {disconnect=265, length=53457, time=1}
# 11                   {disconnect=149, length=28879}
# 12                     {disconnect=16, length=1264}
# 13           {disconnect=256, length=73971, time=2}
# 14          {disconnect=93, length=126384, time=13}
# 15                        {disconnect=9, length=15}
# 16                     {disconnect=204, length=446}
# 17                       {disconnect=7, length=277}
# 18                       {disconnect=24, length=22}
# 19            {disconnect=206, length=7227, time=3}

# %% [markdown]
# The aggregations show which MIME types are mostly affected by truncations.
#
# Now let's look into the reasons of the truncation and load the histograms with reason counts into columns:

# %%
# expand embedded Presto/Athena histogram as columns into data frame
# - transform to valid JSON
data['reasons_truncation'] = data['reasons_truncation'].str.replace('(\\w+)=', '"\\1":', regex=True)
# - load columns in data frame
truncation_reason = data['reasons_truncation'].apply(lambda x: json.loads(x) if type(x) == str else {}).apply(pandas.Series).add_prefix('trunc.')
# - join with original data
data = data.join(truncation_reason)

data['trunc.length.perc'] = 100.0 * data['trunc.length'] / data['n_pages']
data[['content_mime_detected', 'n_pages', 'perc_truncated', 'trunc.length', 'trunc.length.perc']].sort_values(by=['trunc.length'], ascending=False).head(20)
# Out:
#                       content_mime_detected     n_pages  perc_truncated  \
# 0                                 text/html  2002557402        0.757578
# 1                     application/xhtml+xml   555659037        0.719266
# 2                           application/pdf    12206558       24.028182
# 3                                image/jpeg     3932068        9.780960
# 14                               audio/mpeg      147410       85.808290
# 7                           application/xml     1713357        5.201309
# 13                          application/zip      222256       33.397974
# 10                                image/png      584080        9.197884
# 6                                text/plain     2068745        2.289891
# 36                                video/mp4       42645       92.723649
# 40  application/vnd.android.package-archive       39023       94.059913
# 41                                audio/mp4       37268       87.777718
# 31                               image/tiff       54456       59.405759
# 11                 application/octet-stream      329265        8.815999
# 4                       application/rss+xml     3424865        0.627499
# 28                     application/epub+zip       57861       28.482052
# 56                              video/x-m4v       14949       96.193725
# 22                         application/gzip       70255       19.850544
# 66                          video/quicktime       11641       79.769779
# 61                    application/x-dosexec       12853       63.845017
#
#     trunc.length  trunc.length.perc
# 0     13904449.0           0.694335
# 1      3178707.0           0.572061
# 2      2921479.0          23.933684
# 3       382529.0           9.728443
# 14      126384.0          85.736382
# 7        87221.0           5.090650
# 13       73971.0          33.281891
# 10       53457.0           9.152342
# 6        43556.0           2.105431
# 36       39509.0          92.646266
# 40       36580.0          93.739589
# 41       32521.0          87.262531
# 31       32346.0          59.398413
# 11       28879.0           8.770747
# 4        19236.0           0.561657
# 28       16448.0          28.426747
# 56       14323.0          95.812429
# 22       13796.0          19.637037
# 66        9269.0          79.623744
# 61        8200.0          63.798335
