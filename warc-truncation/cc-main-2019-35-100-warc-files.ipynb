# %% [markdown]
# # Truncated Records in WARC Files (August 2019)
#
# This metrics are based on WARC files from the August 2019 crawl (CC-MAIN-2019-35) after fixes and improvements in the WARC writer, cf. [cc/nutch#10](//github.com/commoncrawl/nutch/issues/10) and [metrics based on October 2018 WARC files](./cc-main-2018-43-single-warc-file.ipynb).
#
# Truncated records are extracted using cc-pyspark, see [cc-pyspark#9](//github.com/commoncrawl/cc-pyspark/pull/9) from 100 randomly selected WARC files of the August 2019 crawl listed in [CC-MAIN-2019-35-warc.paths](./data/CC-MAIN-2019-35-warc.paths).

# %%
import pandas

data = pandas.read_csv('data/truncated-records-CC-MAIN-2019-35-warc-100.csv')

# %% [markdown]
# Verify the solution of ([NUTCH-2729](https://issues.apache.org/jira/browse/NUTCH-2729)): all records having exactly the size of the content limit (1 MiB) are likely to be marked as truncated because the probability that a content payload is exactly 1 MiB is low.
#
# There are no unmarked records in the analyzed set:

# %%
data['truncated_reason'].value_counts(dropna=False)
# Out:
# length        26643
# disconnect     4223
# time              2
# Name: truncated_reason, dtype: int64

# %% [markdown]
# Let's only look at pages/documents truncated because of the length limit

# %%
tr = data[data['truncated_reason'] == 'length']

# %% [markdown]
# and check, first, how long the records are (all are exactly 1 MiB):

# %%
tr['payload_length'].value_counts(dropna=False)
# Out:
# 1048576    26643
# Name: payload_length, dtype: int64

# %% [markdown]
# and, second, which content types are truncated:

# %%
tr['identified_payload_type'].value_counts(dropna=False)
# Out:
# text/html                                                                    17989
# application/xhtml+xml                                                         5234
# application/pdf                                                               1496
# image/jpeg                                                                     629
# audio/mpeg                                                                     188
# application/zip                                                                124
# text/plain                                                                      83
# image/png                                                                       82
# application/xml                                                                 69
# application/octet-stream                                                        67
# video/mp4                                                                       56
# audio/mp4                                                                       54
# application/vnd.android.package-archive                                         50
# application/epub+zip                                                            33
# application/rss+xml                                                             29
# image/tiff                                                                      24
# video/x-m4v                                                                     23
# image/jp2                                                                       22
# application/x-tika-ooxml                                                        20
# application/x-rar-compressed                                                    15
# video/x-matroska                                                                15
# video/quicktime                                                                 13
# application/x-tika-msoffice                                                     13
# application/x-xz                                                                12
# application/x-msdownload                                                        11
# image/vnd.djvu                                                                  11
# application/gzip                                                                10
# application/x-dosexec                                                           10
# application/x-sqlite3                                                            9
# application/vnd.openxmlformats-officedocument.presentationml.presentation        9
#                                                                              ...
# multipart/related                                                                1
# application/vnd.google-earth.kmz                                                 1
# application/mxf                                                                  1
# application/vnd.oasis.opendocument.text                                          1
# text/tab-separated-values                                                        1
# binary/octet-stream                                                              1
# application/vnd.rn-realmedia                                                     1
# application/download                                                             1
# application/x-chrome-package                                                     1
# application/octet_stream                                                         1
# application/x-tika-java-web-archive                                              1
# application/gpx+xml                                                              1
# application/x-tar                                                                1
# text/x-php                                                                       1
# image/x-xcf                                                                      1
# model/vnd.dwf; version=6                                                         1
# application/x-unknown                                                            1
# application/x-sharedlib                                                          1
# model/vnd.mts                                                                    1
# application/x-stuffit                                                            1
# application/zlib                                                                 1
# application/vnd.oasis.opendocument.spreadsheet                                   1
# application/vnd.ms-htmlhelp                                                      1
# application/wsdl+xml                                                             1
# text/x-perl                                                                      1
# text/x-log                                                                       1
# application/vnd.symbian.install                                                  1
# application/x-lzma                                                               1
# application/x-fictionbook+xml                                                    1
# application/x-doom                                                               1
# Name: identified_payload_type, Length: 127, dtype: int64

# %% [markdown]
# Now let's check records records truncated by another reason than the payload length:

# %%
tr = data[data['truncated_reason'] != 'length']
tr['payload_length'].mean()/1024
# Out:
# 69.48091808431953

# %% [markdown]
# The average size (after truncation) is significantly lower than 1 MiB, and the amount of HTML pages among the truncated document types is larger:

# %%
tr['identified_payload_type'].value_counts(dropna=False)
# Out:
# text/html                                  2571
# application/xhtml+xml                      1615
# application/pdf                              12
# image/jpeg                                    7
# application/xml                               4
# application/vnd.android.package-archive       4
# video/x-matroska                              3
# text/plain                                    2
# text/x-vcard                                  2
# text/calendar                                 1
# application/x-tika-msoffice                   1
# application/gzip                              1
# application/octet-stream                      1
# text/x-matlab                                 1
# Name: identified_payload_type, dtype: int64

# %% [markdown]
# Now let's look into WARC records sizes of all records truncated because of the length limit.
#
# Because Common Crawl uses gzipped WARC files as primary archive format, it's actually more the size of the gzip-compressed WARC records which matters, not the size of the uncompressed content payload. Let's put the compressed and uncompressed lengths into relation for the various content types:

# %%
data['count'] = 1
tr = data[data['truncated_reason'] == 'length']
tr = tr[['warc_record_length', 'warc_content_length', 'payload_length', 'identified_payload_type', 'count']]
r = tr.groupby(['identified_payload_type']).sum()
r = r[r['count'] > 3] # drop rare document types
r['% ratio'] = 100.0*r['warc_record_length']/r['warc_content_length']
for col in ['warc_record_length', 'warc_content_length', 'payload_length']:
    r[col] = r[col]/2**20 # show aggregated length in MiB
r
# Out:
#                                                     warc_record_length  \
# identified_payload_type
# application/atom+xml                                          0.869540
# application/epub+zip                                         32.613303
# application/fits                                              5.050832
# application/gzip                                              9.990907
# application/json                                              0.743587
# application/msword                                            4.433574
# application/octet-stream                                     54.735172
# application/pdf                                            1342.943089
# application/rdf+xml                                           0.356032
# application/rss+xml                                           7.564011
# application/vnd.android.package-archive                      47.160984
# application/vnd.apple.keynote                                 2.554733
# application/vnd.ms-cab-compressed                             3.979851
# application/vnd.ms-excel                                      4.267982
# application/vnd.ms-excel.sheet.macroenabled.12                2.905040
# application/vnd.openxmlformats-officedocument.p...            8.580071
# application/vnd.openxmlformats-officedocument.p...            4.844024
# application/vnd.openxmlformats-officedocument.s...            4.380686
# application/vnd.openxmlformats-officedocument.w...            5.202519
# application/x-bzip2                                           4.990857
# application/x-dosexec                                         9.020029
# application/x-executable                                      2.235464
# application/x-matlab-data                                     3.984825
# application/x-mobipocket-ebook                                6.617245
# application/x-msdownload                                      9.062288
# application/x-netcdf                                          4.380427
# application/x-rar-compressed                                 14.943167
# application/x-sqlite3                                         6.531251
# application/x-tika-msoffice                                   7.662450
# application/x-tika-ooxml                                     18.606666
# application/x-xz                                             12.012914
# application/xhtml+xml                                       545.214047
# application/xml                                               6.134201
# application/zip                                             119.394981
# audio/aacp                                                    4.908386
# audio/mp4                                                    45.456213
# audio/mpeg                                                  180.990018
# audio/vnd.wave                                                3.640565
# image/gif                                                     6.925201
# image/jp2                                                    21.721440
# image/jpeg                                                  613.409774
# image/png                                                    79.517721
# image/tiff                                                   15.193893
# image/vnd.djvu                                               10.900711
# image/vnd.dxf; format=ascii                                   0.862187
# message/rfc822                                                2.875202
# text/csv                                                      0.887983
# text/html                                                  2427.349087
# text/plain                                                   22.594495
# video/mp4                                                    47.430221
# video/quicktime                                               9.999593
# video/x-m4v                                                  18.187607
# video/x-matroska                                             14.606286
# video/x-ms-wmv                                                6.908782
#
#                                                     warc_content_length  \
# identified_payload_type
# application/atom+xml                                           7.003787
# application/epub+zip                                          33.015307
# application/fits                                               8.002682
# application/gzip                                              10.003711
# application/json                                               6.002691
# application/msword                                             7.003987
# application/octet-stream                                      67.029173
# application/pdf                                             1496.863754
# application/rdf+xml                                            4.001985
# application/rss+xml                                           29.014924
# application/vnd.android.package-archive                       50.021399
# application/vnd.apple.keynote                                  4.001133
# application/vnd.ms-cab-compressed                              4.001675
# application/vnd.ms-excel                                       7.004300
# application/vnd.ms-excel.sheet.macroenabled.12                 4.001408
# application/vnd.openxmlformats-officedocument.p...             9.005498
# application/vnd.openxmlformats-officedocument.p...             5.002331
# application/vnd.openxmlformats-officedocument.s...             5.002964
# application/vnd.openxmlformats-officedocument.w...             6.003886
# application/x-bzip2                                            5.001765
# application/x-dosexec                                         10.005198
# application/x-executable                                       4.001236
# application/x-matlab-data                                      4.001191
# application/x-mobipocket-ebook                                 7.002567
# application/x-msdownload                                      11.004780
# application/x-netcdf                                           5.001725
# application/x-rar-compressed                                  15.007457
# application/x-sqlite3                                          9.002322
# application/x-tika-msoffice                                   13.006509
# application/x-tika-ooxml                                      20.012081
# application/x-xz                                              12.004364
# application/xhtml+xml                                       5237.248244
# application/xml                                               69.036091
# application/zip                                              124.060803
# audio/aacp                                                     5.002485
# audio/mp4                                                     54.023660
# audio/mpeg                                                   188.099800
# audio/vnd.wave                                                 4.002071
# image/gif                                                      7.002302
# image/jp2                                                     22.011274
# image/jpeg                                                   629.300128
# image/png                                                     82.038562
# image/tiff                                                    24.009665
# image/vnd.djvu                                                11.004930
# image/vnd.dxf; format=ascii                                    8.003930
# message/rfc822                                                 4.001775
# text/csv                                                       4.001406
# text/html                                                  18005.054215
# text/plain                                                    83.033493
# video/mp4                                                     56.027861
# video/quicktime                                               13.006680
# video/x-m4v                                                   23.007877
# video/x-matroska                                              15.004769
# video/x-ms-wmv                                                 7.002127
#
#                                                     payload_length  count  \
# identified_payload_type
# application/atom+xml                                           7.0      7
# application/epub+zip                                          33.0     33
# application/fits                                               8.0      8
# application/gzip                                              10.0     10
# application/json                                               6.0      6
# application/msword                                             7.0      7
# application/octet-stream                                      67.0     67
# application/pdf                                             1496.0   1496
# application/rdf+xml                                            4.0      4
# application/rss+xml                                           29.0     29
# application/vnd.android.package-archive                       50.0     50
# application/vnd.apple.keynote                                  4.0      4
# application/vnd.ms-cab-compressed                              4.0      4
# application/vnd.ms-excel                                       7.0      7
# application/vnd.ms-excel.sheet.macroenabled.12                 4.0      4
# application/vnd.openxmlformats-officedocument.p...             9.0      9
# application/vnd.openxmlformats-officedocument.p...             5.0      5
# application/vnd.openxmlformats-officedocument.s...             5.0      5
# application/vnd.openxmlformats-officedocument.w...             6.0      6
# application/x-bzip2                                            5.0      5
# application/x-dosexec                                         10.0     10
# application/x-executable                                       4.0      4
# application/x-matlab-data                                      4.0      4
# application/x-mobipocket-ebook                                 7.0      7
# application/x-msdownload                                      11.0     11
# application/x-netcdf                                           5.0      5
# application/x-rar-compressed                                  15.0     15
# application/x-sqlite3                                          9.0      9
# application/x-tika-msoffice                                   13.0     13
# application/x-tika-ooxml                                      20.0     20
# application/x-xz                                              12.0     12
# application/xhtml+xml                                       5234.0   5234
# application/xml                                               69.0     69
# application/zip                                              124.0    124
# audio/aacp                                                     5.0      5
# audio/mp4                                                     54.0     54
# audio/mpeg                                                   188.0    188
# audio/vnd.wave                                                 4.0      4
# image/gif                                                      7.0      7
# image/jp2                                                     22.0     22
# image/jpeg                                                   629.0    629
# image/png                                                     82.0     82
# image/tiff                                                    24.0     24
# image/vnd.djvu                                                11.0     11
# image/vnd.dxf; format=ascii                                    8.0      8
# message/rfc822                                                 4.0      4
# text/csv                                                       4.0      4
# text/html                                                  17989.0  17989
# text/plain                                                    83.0     83
# video/mp4                                                     56.0     56
# video/quicktime                                               13.0     13
# video/x-m4v                                                   23.0     23
# video/x-matroska                                              15.0     15
# video/x-ms-wmv                                                 7.0      7
#
#                                                        % ratio
# identified_payload_type
# application/atom+xml                                 12.415286
# application/epub+zip                                 98.782370
# application/fits                                     63.114240
# application/gzip                                     99.872007
# application/json                                     12.387553
# application/msword                                   63.300710
# application/octet-stream                             81.658731
# application/pdf                                      89.717123
# application/rdf+xml                                   8.896395
# application/rss+xml                                  26.069379
# application/vnd.android.package-archive              94.281618
# application/vnd.apple.keynote                        63.850247
# application/vnd.ms-cab-compressed                    99.454631
# application/vnd.ms-excel                             60.933747
# application/vnd.ms-excel.sheet.macroenabled.12       72.600446
# application/vnd.openxmlformats-officedocument.p...   95.275925
# application/vnd.openxmlformats-officedocument.p...   96.835334
# application/vnd.openxmlformats-officedocument.s...   87.561809
# application/vnd.openxmlformats-officedocument.w...   86.652532
# application/x-bzip2                                  99.781914
# application/x-dosexec                                90.153433
# application/x-executable                             55.869339
# application/x-matlab-data                            99.590972
# application/x-mobipocket-ebook                       94.497410
# application/x-msdownload                             82.348656
# application/x-netcdf                                 87.578329
# application/x-rar-compressed                         99.571613
# application/x-sqlite3                                72.550735
# application/x-tika-msoffice                          58.912426
# application/x-tika-ooxml                             92.977165
# application/x-xz                                    100.071222
# application/xhtml+xml                                10.410315
# application/xml                                       8.885499
# application/zip                                      96.239084
# audio/aacp                                           98.118954
# audio/mp4                                            84.141306
# audio/mpeg                                           96.220207
# audio/vnd.wave                                       90.967016
# image/gif                                            98.898923
# image/jp2                                            98.683247
# image/jpeg                                           97.474916
# image/png                                            96.927249
# image/tiff                                           63.282406
# image/vnd.djvu                                       99.052984
# image/vnd.dxf; format=ascii                          10.772050
# message/rfc822                                       71.848176
# text/csv                                             22.191784
# text/html                                            13.481487
# text/plain                                           27.211302
# video/mp4                                            84.654706
# video/quicktime                                      76.880437
# video/x-m4v                                          79.049477
# video/x-matroska                                     97.344289
# video/x-ms-wmv                                       98.666909

# %% [markdown]
# Note that the `warc_record_length` also includes the WARC headers while `warc_content_length` does not. That's why the compression ratio can exceed 100%.

# %% [markdown]
# Finally, a short look into super-large captures with an original `Content-Length` HTTP header exceeding 1 GiB:

# %%
data[data['http_orig_content_length'] > 2**30].groupby(['identified_payload_type']).sum()
# Out:
#                           warc_record_offset  warc_record_length  \
# identified_payload_type
# application/octet-stream             7497503              742809
# application/x-tar                  126888947              950904
# application/zip                    474064537             3119285
# model/vnd.mts                      146964408             1035285
# video/mp4                         1095804704             1145435
# video/mpeg                         195450414             1023648
# video/x-matroska                   199548452             3132836
#
#                           warc_content_length  http_content_length  \
# identified_payload_type
# application/octet-stream              1049026              1048576
# application/x-tar                     1048870              1048576
# application/zip                       3147708              3145728
# model/vnd.mts                         1048917              1048576
# video/mp4                             2098097              2097152
# video/mpeg                            1048880              1048576
# video/x-matroska                      3177048              3175878
#
#                           payload_length  http_orig_content_length  count
# identified_payload_type
# application/octet-stream         1048576                2073100288      1
# application/x-tar                1048576                6430743040      1
# application/zip                  3145728                4086519668      3
# model/vnd.mts                    1048576                2045650944      1
# video/mp4                        2097152                3006448624      2
# video/mpeg                       1048576                1785134452      1
# video/x-matroska                 3175878                6035122172      4
